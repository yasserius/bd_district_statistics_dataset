# %%
import glob
import pandas as pd

from pprint import pprint

# %%
csv_dir = "./cleaned_CSVs/*"

zilas = glob.glob(csv_dir)

print(zilas[:10])
# Out:
# ['./cleaned_CSVs\\Bagerhat', './cleaned_CSVs\\Bandarban', './cleaned_CSVs\\Barguna', './cleaned_CSVs\\Barisal', './cleaned_CSVs\\Bhola', './cleaned_CSVs\\Bogra', './cleaned_CSVs\\B_Baria', './cleaned_CSVs\\Chandpur', './cleaned_CSVs\\ChapaiNawabganj', './cleaned_CSVs\\Chittagong']

# %%
for zila in zilas:
    zila_name = zila.split('\\')[-1]
    
    output_html = """
        <head>
          <style>
          table {
            font-family: Arial, Helvetica, sans-serif;
            border-collapse: collapse;
            width: 100%;
          }

          table td, table th {
            border: 1px solid #ddd;
            padding: 8px;
          }

          table tr:nth-child(even){background-color: #f2f2f2;}

          #customers tr:hover {background-color: #ddd;}

          table th {
            padding-top: 12px;
            padding-bottom: 12px;
            text-align: left;
            background-color: #4CAF50;
            color: white;
          }
          </style>
        </head>
        <body>"""
    
    output_html +=  "<h1>{}</h1><br>".format(zila_name)
    
#     print('\n\n\nZila:', zila.split('\\')[-1])
    for f in glob.glob(zila + '/*.csv'):
        df = pd.read_csv(f, index_col=0)
        
        folder_name = f.replace('CSVs_4', 'cleaned_CSVs')
        
        output_html += '\n<br>\n' + \
                        '<h2>{}</h2>\n'.format(folder_name) + \
                        df.to_html(na_rep='')
    
    output_html += "</body>"
    
    
    export_dir = zila + "/tables.html"
    with open(export_dir, "w", encoding='utf-8') as f:
        f.write(output_html)
        print("HTML file created:", export_dir)
# Out:
# HTML file created: ./cleaned_CSVs\Bagerhat/tables.html
# HTML file created: ./cleaned_CSVs\Bandarban/tables.html
# HTML file created: ./cleaned_CSVs\Barguna/tables.html
# HTML file created: ./cleaned_CSVs\Barisal/tables.html
# HTML file created: ./cleaned_CSVs\Bhola/tables.html
# HTML file created: ./cleaned_CSVs\Bogra/tables.html
# HTML file created: ./cleaned_CSVs\B_Baria/tables.html
# HTML file created: ./cleaned_CSVs\Chandpur/tables.html
# HTML file created: ./cleaned_CSVs\ChapaiNawabganj/tables.html
# HTML file created: ./cleaned_CSVs\Chittagong/tables.html
# HTML file created: ./cleaned_CSVs\Chuadanga/tables.html
# HTML file created: ./cleaned_CSVs\Comilla/tables.html
# HTML file created: ./cleaned_CSVs\CoxsBazar/tables.html
# HTML file created: ./cleaned_CSVs\Dhaka/tables.html
# HTML file created: ./cleaned_CSVs\Dinajpur/tables.html
# HTML file created: ./cleaned_CSVs\Faridpur/tables.html
# HTML file created: ./cleaned_CSVs\Feni/tables.html
# HTML file created: ./cleaned_CSVs\Gaibandha/tables.html
# HTML file created: ./cleaned_CSVs\Gazipur/tables.html
# HTML file created: ./cleaned_CSVs\Gopalgonj/tables.html
# HTML file created: ./cleaned_CSVs\Habiganj/tables.html
# HTML file created: ./cleaned_CSVs\Jamalpur/tables.html
# HTML file created: ./cleaned_CSVs\Jessore/tables.html
# HTML file created: ./cleaned_CSVs\Jhalkathi/tables.html
# HTML file created: ./cleaned_CSVs\Jhinaidaha/tables.html
# HTML file created: ./cleaned_CSVs\Joypurhat/tables.html
# HTML file created: ./cleaned_CSVs\Khagrachori/tables.html
# HTML file created: ./cleaned_CSVs\Khulna/tables.html
# HTML file created: ./cleaned_CSVs\Kishoreganj/tables.html
# HTML file created: ./cleaned_CSVs\Kurigram/tables.html
# HTML file created: ./cleaned_CSVs\Kushtia/tables.html
# HTML file created: ./cleaned_CSVs\Lalmonirhat/tables.html
# HTML file created: ./cleaned_CSVs\Laxmipur/tables.html
# HTML file created: ./cleaned_CSVs\Madaripur/tables.html
# HTML file created: ./cleaned_CSVs\Magura/tables.html
# HTML file created: ./cleaned_CSVs\Manikganj/tables.html
# HTML file created: ./cleaned_CSVs\Meherpur/tables.html
# HTML file created: ./cleaned_CSVs\Moulvibazar/tables.html
# HTML file created: ./cleaned_CSVs\Munshiganj/tables.html
# HTML file created: ./cleaned_CSVs\Mymensingh/tables.html
# HTML file created: ./cleaned_CSVs\Naogaon/tables.html
# HTML file created: ./cleaned_CSVs\Narail/tables.html
# HTML file created: ./cleaned_CSVs\Narayanganj/tables.html
# HTML file created: ./cleaned_CSVs\Narsingdi/tables.html
# HTML file created: ./cleaned_CSVs\Natore/tables.html
# HTML file created: ./cleaned_CSVs\Netrokona/tables.html
# HTML file created: ./cleaned_CSVs\Nilphamari/tables.html
# HTML file created: ./cleaned_CSVs\Noakhali/tables.html
# HTML file created: ./cleaned_CSVs\Pabna/tables.html
# HTML file created: ./cleaned_CSVs\Panchagor/tables.html
# HTML file created: ./cleaned_CSVs\Patuakhali/tables.html
# HTML file created: ./cleaned_CSVs\Pirojpur/tables.html
# HTML file created: ./cleaned_CSVs\Rajbari/tables.html
# HTML file created: ./cleaned_CSVs\Rajshahi/tables.html
# HTML file created: ./cleaned_CSVs\Rangamati/tables.html
# HTML file created: ./cleaned_CSVs\Rangpur/tables.html
# HTML file created: ./cleaned_CSVs\Satkhira/tables.html
# HTML file created: ./cleaned_CSVs\Shariatpur/tables.html
# HTML file created: ./cleaned_CSVs\Sherpur/tables.html
# HTML file created: ./cleaned_CSVs\Sirajganj/tables.html
# HTML file created: ./cleaned_CSVs\Sunamganj/tables.html
# HTML file created: ./cleaned_CSVs\Sylhet/tables.html
# HTML file created: ./cleaned_CSVs\Tangail/tables.html
# HTML file created: ./cleaned_CSVs\Thakurgaon/tables.html
