# %%
import pandas as pd
upozila = 'Gaibandha' #status-done
upozila = 'Faridpur' # status - done
upozila = 'Feni' # status - done
upozila = 'Gazipur' # status - done
upozila = 'Gopalgonj' # status - done
upozila = 'Habiganj' # status - done
upozila = 'Jamalpur' # status - done
upozila = 'Jessore' # status - done
upozila = 'Jhalkathi'
filepath = 'cleaned_CSVs/' + upozila + '/splitted_columns/'

# data = pd.read_csv(filename, skiprows=3, header=None, usecols=[1, 2, 3, 4])

# %%
# data.to_csv('test.csv')

# %%
filename = filepath + 'CHAPTER 3_Temperature, rainfall, humidity during the years 2008-2011.csv'
# filename = filepath + 'CHAPTER 10_Gazipur Town 2011 (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Kaliakair Town 2011  (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Kaliganj Town 2011  (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Sreepur Town 2011 (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Tongi Town 2011 (Population and Housing Census).csv'
data = pd.read_csv(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-cfda43f871ea> in <module>
#       5 # filename = filepath + 'CHAPTER 10_Sreepur Town 2011 (Population and Housing Census).csv'
#       6 # filename = filepath + 'CHAPTER 10_Tongi Town 2011 (Population and Housing Census).csv'
# ----> 7 data = pd.read_csv(filename)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File cleaned_CSVs/Jhalkathi/splitted_columns/CHAPTER 3_Temperature, rainfall, humidity during the years 2008-2011.csv does not exist: 'cleaned_CSVs/Jhalkathi/splitted_columns/CHAPTER 3_Temperature, rainfall, humidity during the years 2008-2011.csv'

# %%
data
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  Temperature, rainfall, humidity during the yea...
# 1           1                                                NaN
# 2           2                                              Years
# 3           3                                              Years
# 4           4                                               2008
# 5           5                                               2009
# 6           6                                               2010
# 7           7                                               2011
#
#                           1                         2                       3  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2  Temperature (centigrade)  Temperature (centigrade)   Rainfall (millimeter)
# 3                   Maximum                   Minimum   Rainfall (millimeter)
# 4                      36.2                       9.9                    1809
# 5                      38.2                      11.1                    1647
# 6                      37.6                       9.9                    1026
# 7                      24.8                       9.3                    1374
#
#                4
# 0            NaN
# 1            NaN
# 2   Humidity (%)
# 3   Humidity (%)
# 4           80.0
# 5           77.0
# 6           63.1
# 7           77.2

# %%
columns = data.columns
columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4'], dtype='object')

# %%
for row, item in data.iterrows():
#     print(item.str.replace(str1, ''))
    if row == 2:
        print('I am in row lalala', item)
        col = 0
        for raw_str in item:
            next_row = data.iloc[row+1, col]
            if (col!= 0) and (data.iloc[row, col] != next_row): # ignore column 0
                

                # update
                data.iloc[row, col] =  data.iloc[row, col] + ' ' + next_row
                print(data.iloc[row, col])
            
            col = col + 1
# Out:
# I am in row lalala Unnamed: 0                           2
# 0                                Years
# 1             Temperature (centigrade)
# 2             Temperature (centigrade)
# 3                Rainfall (millimeter)
# 4                         Humidity (%)
# Name: 2, dtype: object
# Temperature (centigrade) Maximum
# Temperature (centigrade) Minimum

# %%
# data after cleaned
data
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  Temperature, rainfall, humidity during the yea...
# 1           1                                                NaN
# 2           2                                              Years
# 3           3                                              Years
# 4           4                                               2008
# 5           5                                               2009
# 6           6                                               2010
# 7           7                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 3                           Maximum                           Minimum
# 4                              36.2                               9.9
# 5                              38.2                              11.1
# 6                              37.6                               9.9
# 7                              24.8                               9.3
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 3   Rainfall (millimeter)   Humidity (%)
# 4                    1809           80.0
# 5                    1647           77.0
# 6                    1026           63.1
# 7                    1374           77.2

# %%
# drop redundant rows
data.drop([3], axis=0, inplace=True)
# drop one extra column
data.drop(columns[0], axis=1, inplace=True)
data
# Out:
#                                                    0  \
# 0  Temperature, rainfall, humidity during the yea...
# 1                                                NaN
# 2                                              Years
# 4                                               2008
# 5                                               2009
# 6                                               2010
# 7                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 4                              36.2                               9.9
# 5                              38.2                              11.1
# 6                              37.6                               9.9
# 7                              24.8                               9.3
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 4                    1809           80.0
# 5                    1647           77.0
# 6                    1026           63.1
# 7                    1374           77.2

# %%
# reset the index after dropping rows
data = data.reset_index(drop=True)

# %%
data
# Out:
#                                                    0  \
# 0  Temperature, rainfall, humidity during the yea...
# 1                                                NaN
# 2                                              Years
# 3                                               2008
# 4                                               2009
# 5                                               2010
# 6                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 3                              36.2                               9.9
# 4                              38.2                              11.1
# 5                              37.6                               9.9
# 6                              24.8                               9.3
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 3                    1809           80.0
# 4                    1647           77.0
# 5                    1026           63.1
# 6                    1374           77.2

# %%
# overwrite to the same file
# data = data.reset_index()
data.to_csv(filename, index=True)

# %%
data
# Out:
#                                                    0  \
# 0  Temperature, rainfall, humidity during the yea...
# 1                                                NaN
# 2                                              Years
# 3                                               2008
# 4                                               2009
# 5                                               2010
# 6                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 3                              34.1                               8.2
# 4                              33.2                              10.7
# 5                              34.0                               8.7
# 6                              23.7                               8.6
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 3                    3356           79.0
# 4                    2407           78.0
# 5                    1868           63.7
# 6                    2071           78.8
