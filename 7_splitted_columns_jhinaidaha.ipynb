# %%
import pandas as pd
upozila = 'Gaibandha' #status-done
upozila = 'Faridpur' # status - done
upozila = 'Feni' # status - done
upozila = 'Gazipur' # status - done
upozila = 'Gopalgonj' # status - done
upozila = 'Habiganj' # status - done
upozila = 'Jamalpur' # status - done
upozila = 'Jessore' # status - done
upozila = 'Jhalkathi' # status - done
upozila = 'Jhinaidaha'
filepath = 'cleaned_CSVs/' + upozila + '/splitted_columns/'

# data = pd.read_csv(filename, skiprows=3, header=None, usecols=[1, 2, 3, 4])

# %%
# data.to_csv('test.csv')

# %%
import glob
txtfiles = []
for file in glob.glob(filepath + 'CHAPTER 3_' + '*.csv'):
    txtfiles.append(file)
txtfiles # 9 files
# Out:
# ['cleaned_CSVs/Jhinaidaha/splitted_columns/CHAPTER 3_Temperature, rainfall, humidity during the years 2008-2011.csv']

# %%
# filename = filepath + 'CHAPTER 3_Temperature, rainfall, humidity during the years 2008-2011.csv'
# filename = filepath + 'CHAPTER 10_Gazipur Town 2011 (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Kaliakair Town 2011  (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Kaliganj Town 2011  (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Sreepur Town 2011 (Population and Housing Census).csv'
# filename = filepath + 'CHAPTER 10_Tongi Town 2011 (Population and Housing Census).csv'
# data = pd.read_csv(filename)
index = 0
filename= txtfiles[index]
data = pd.read_csv(filename)
columns = data.columns
columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4'], dtype='object')

# %%
data
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  Temperature, rainfall, humidity during the yea...
# 1           1                                                NaN
# 2           2                                              Years
# 3           3                                              Years
# 4           4                                               2008
# 5           5                                               2009
# 6           6                                               2010
# 7           7                                               2011
#
#                           1                         2                       3  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2  Temperature (centigrade)  Temperature (centigrade)   Rainfall (millimeter)
# 3                   Maximum                   Minimum   Rainfall (millimeter)
# 4                      35.2                       9.6                    1834
# 5                      37.4                      11.4                    1224
# 6                      34.7                       8.7                     587
# 7                      23.3                       8.6                    1620
#
#                4
# 0            NaN
# 1            NaN
# 2   Humidity (%)
# 3   Humidity (%)
# 4           79.0
# 5           75.0
# 6           63.8
# 7           78.0

# %%
for row, item in data.iterrows():
#     print(item.str.replace(str1, ''))
    if row == 2:
        print('I am in row lalala', item)
        col = 0
        for raw_str in item:
            next_row = data.iloc[row+1, col]
            if (col!= 0) and (data.iloc[row, col] != next_row): # ignore column 0
                

                # update
                data.iloc[row, col] =  data.iloc[row, col] + ' ' + next_row
                print(data.iloc[row, col])
            
            col = col + 1
# Out:
# I am in row lalala Unnamed: 0                           2
# 0                                Years
# 1             Temperature (centigrade)
# 2             Temperature (centigrade)
# 3                Rainfall (millimeter)
# 4                         Humidity (%)
# Name: 2, dtype: object
# Temperature (centigrade) Maximum
# Temperature (centigrade) Minimum

# %%
for row, item in data.iterrows():
#     print(item.str.replace(str1, ''))
    if row == 2:
        print('I am in row lalala', item)
        col = 0
        for raw_str in item:
            next_row = data.iloc[row+2, col]
            if (col!= 0) and (data.iloc[row, col] != next_row): # ignore column 0
                

                # update
                data.iloc[row, col] =  data.iloc[row, col] + ' ' + next_row
                print(data.iloc[row, col])
            
            col = col + 1
# Out:
# I am in row lalala Unnamed: 0                                                  2
# 0                                                     Upazila
# 1                   Number of  hospital/ clinic/ nursing home
# 2                                               Number of bed
# 3                                           Number of  doctor
# 4                                             Number of nurse
# 5                                     Number of    technician
# 6                                       Number of other staff
# 7              Number of patient under health facility Indoor
# 8              Number of patient under health facility Indoor
# 9             Number of patient under health facility Outdoor
# 10            Number of patient under health facility Outdoor
# Name: 2, dtype: object
# Number of patient under health facility Indoor Male
# Number of patient under health facility Indoor Female
# Number of patient under health facility Outdoor Male
# Number of patient under health facility Outdoor Female

# %%
# data after cleaned
data
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  Temperature, rainfall, humidity during the yea...
# 1           1                                                NaN
# 2           2                                              Years
# 3           3                                              Years
# 4           4                                               2008
# 5           5                                               2009
# 6           6                                               2010
# 7           7                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 3                           Maximum                           Minimum
# 4                              35.2                               9.6
# 5                              37.4                              11.4
# 6                              34.7                               8.7
# 7                              23.3                               8.6
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 3   Rainfall (millimeter)   Humidity (%)
# 4                    1834           79.0
# 5                    1224           75.0
# 6                     587           63.8
# 7                    1620           78.0

# %%
# drop redundant rows
data.drop([3], axis=0, inplace=True)
# drop one extra column
data.drop(columns[0], axis=1, inplace=True)
data
# Out:
#                                                    0  \
# 0  Temperature, rainfall, humidity during the yea...
# 1                                                NaN
# 2                                              Years
# 4                                               2008
# 5                                               2009
# 6                                               2010
# 7                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 4                              35.2                               9.6
# 5                              37.4                              11.4
# 6                              34.7                               8.7
# 7                              23.3                               8.6
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 4                    1834           79.0
# 5                    1224           75.0
# 6                     587           63.8
# 7                    1620           78.0

# %%
# reset the index after dropping rows
data = data.reset_index(drop=True)

# %%
data
# Out:
#                                                    0  \
# 0  Temperature, rainfall, humidity during the yea...
# 1                                                NaN
# 2                                              Years
# 3                                               2008
# 4                                               2009
# 5                                               2010
# 6                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 3                              35.2                               9.6
# 4                              37.4                              11.4
# 5                              34.7                               8.7
# 6                              23.3                               8.6
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 3                    1834           79.0
# 4                    1224           75.0
# 5                     587           63.8
# 6                    1620           78.0

# %%
# overwrite to the same file
# data = data.reset_index()
data.to_csv(filename, index=True)

# %%
data
# Out:
#                                                    0  \
# 0  Temperature, rainfall, humidity during the yea...
# 1                                                NaN
# 2                                              Years
# 3                                               2008
# 4                                               2009
# 5                                               2010
# 6                                               2011
#
#                                   1                                 2  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2  Temperature (centigrade) Maximum  Temperature (centigrade) Minimum
# 3                              35.2                               9.6
# 4                              37.4                              11.4
# 5                              34.7                               8.7
# 6                              23.3                               8.6
#
#                         3              4
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2   Rainfall (millimeter)   Humidity (%)
# 3                    1834           79.0
# 4                    1224           75.0
# 5                     587           63.8
# 6                    1620           78.0

# %%
filename
# Out:
# 'cleaned_CSVs/Jhinaidaha/splitted_columns/CHAPTER 12_Number of Non-government health complex and health facility 2011.csv'
